# %%
import pytesseract
from PIL import Image
import cv2
import numpy as np
import pandas as pd

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract.exe'

# %%
test = (pytesseract.image_to_string(r'C:\\Users\\mypc\\Desktop\\sperated\\seperated_from_images\\QPT1\\4.jpg'))

# %%
test
# Out:
# "4. Consider the following pairs 2\n\nProgramme/Project Ministry\n1. Drought-Pror1e : Ministry of\nArea Programme Agriculture\n2. Desert Development : ' Ministry of\nProgramme Environment\n\nand Forests\n\n3. National Watershed : Ministry\n\nDevelopment Project of Rural\nfor Rainfed Areas Development\n\nWhich of the above pairs is/are\ncorrectly matched?"

# %%
test1 = test.replace('\n', ' ')

# %%
import nltk

lines = test1
# function to test if something is a noun
is_noun = lambda pos: pos[:2] == 'NN' 
is_VB = lambda pos: pos[:2] == 'VB'
is_JJ = lambda pos: pos[:2] == 'JJ'

# %%
tokenized = nltk.word_tokenize(lines)
nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if is_noun(pos) or is_VB(pos)  or 
         is_JJ(pos) ] 

print(nouns)
# Out:
# ['Consider', 'following', 'pairs', 'Programme/Project', 'Ministry', 'Drought-Pror1e', 'Ministry', 'Area', 'Programme', 'Agriculture', 'Desert', 'Development', 'Ministry', 'Programme', 'Environment', 'Forests', 'National', 'Watershed', 'Ministry', 'Development', 'Project', 'Rural', 'Rainfed', 'Areas', 'Development', 'Which', 'above', 'pairs', 'is/are', 'matched']

# %%
t1 = ' '.join(nouns)

# %%
t1
# Out:
# 'Consider following pairs Programme/Project Ministry Drought-Pror1e Ministry Area Programme Agriculture Desert Development Ministry Programme Environment Forests National Watershed Ministry Development Project Rural Rainfed Areas Development Which above pairs is/are matched'

# %%
nltk.pos_tag(tokenized)
# Out:
# [('4', 'CD'),
#  ('.', '.'),
#  ('Consider', 'VB'),
#  ('the', 'DT'),
#  ('following', 'JJ'),
#  ('pairs', 'NNS'),
#  ('2', 'CD'),
#  ('Programme/Project', 'NNP'),
#  ('Ministry', 'NNP'),
#  ('1', 'CD'),
#  ('.', '.'),
#  ('Drought-Pror1e', 'NN'),
#  (':', ':'),
#  ('Ministry', 'NNP'),
#  ('of', 'IN'),
#  ('Area', 'NNP'),
#  ('Programme', 'NNP'),
#  ('Agriculture', 'NNP'),
#  ('2', 'CD'),
#  ('.', '.'),
#  ('Desert', 'NNP'),
#  ('Development', 'NNP'),
#  (':', ':'),
#  ("'", 'POS'),
#  ('Ministry', 'NNP'),
#  ('of', 'IN'),
#  ('Programme', 'NNP'),
#  ('Environment', 'NNP'),
#  ('and', 'CC'),
#  ('Forests', 'NNP'),
#  ('3', 'CD'),
#  ('.', '.'),
#  ('National', 'NNP'),
#  ('Watershed', 'VBD'),
#  (':', ':'),
#  ('Ministry', 'NNP'),
#  ('Development', 'NNP'),
#  ('Project', 'NNP'),
#  ('of', 'IN'),
#  ('Rural', 'NNP'),
#  ('for', 'IN'),
#  ('Rainfed', 'NNP'),
#  ('Areas', 'NNP'),
#  ('Development', 'NNP'),
#  ('Which', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('above', 'JJ'),
# ...

# %%
import spacy
from nltk import Tree


en_nlp = spacy.load('en_core_web_sm')

doc = en_nlp(u'' + t1) 
#for chunk in doc.noun_chunks:
#    print(chunk.text, chunk.root.text, chunk.root.dep_,
#            chunk.root.head.text)
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
    
#print(sent.root)
def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(node.orth_, [to_nltk_tree(child) for child in node.children])
    else:
        return node.orth_


#print(find_root(doc))
[to_nltk_tree(sent.root).pretty_print() for sent in doc.sents]
spacy.displacy.serve(doc, style='dep',  options={'distance': 90})
# Out:
# Programme/Project Ministry Drought-Pror1e Ministry Area Programme Agriculture Desert Development Ministry Programme Environment Forests National Watershed Ministry Development Project Rural Rainfed Areas Development Which 25 246 ORG
#                                                                                                     Consider
#                                                                                   _____________________|__________________________________________________________________________
#                                                                              following                                                                                            |
#                                              ____________________________________|______________________________________________________________                                  |
# ...

# %%
# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token for token in doc if token.pos_ == "VERB"])
# Out:
# Noun phrases: ['pairs Programme/Project Ministry Drought-Pror1e Ministry Area Programme Agriculture Desert Development Ministry', 'Programme Environment Forests', 'National Watershed Ministry Development Project Rural Rainfed Areas Development', 'pairs']
# Verbs: [Consider, following, matched]

# %%
import nltk
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\mypc\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
t1
# Out:
# 'Consider following pairs Programme/Project Ministry Drought-Pror1e Ministry Area Programme Agriculture Desert Development Ministry Programme Environment Forests National Watershed Ministry Development Project Rural Rainfed Areas Development Which above pairs is/are matched'

# %%
test1='Consider following pairs Programme Project Ministry Drought-Pror1e Ministry Area Programme Agriculture Desert Development Ministry Programme Environment Forests National Watershed Ministry Development Project Rural Rainfed Areas Development '

# %%
import spacy
from spacy import displacy
en_nlp = spacy.load('en_core_web_sm')
doc = en_nlp(u'' + test1) 
displacy.render(doc, style="dep") # (1)
displacy.render(doc, style="ent") # (2)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5b4b8c7741de4ec2b77b8999608481e5-0" class="displacy" width="4775" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Consider</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">following</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
# ...

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(test1)
print('Name Entity: {0}'.format(doc.ents))
# Out:
# Name Entity: (Programme Project Ministry,)

# %%
t1= test.replace("[^a-zA-Z#â€]", " ")

# %%
t1
# Out:
# "4. Consider the following pairs 2\n\nProgramme/Project Ministry\n1. Drought-Pror1e : Ministry of\nArea Programme Agriculture\n2. Desert Development : ' Ministry of\nProgramme Environment\n\nand Forests\n\n3. National Watershed : Ministry\n\nDevelopment Project of Rural\nfor Rainfed Areas Development\n\nWhich of the above pairs is/are\ncorrectly matched?"

# %%
new_string = ' '.join([w for w in t1.split() if len(w)>3])

# %%
n1=new_string.replace("/"," ")

# %%
n2 = n1.lower()

# %%
from nltk.corpus import stopwords
stop = stopwords.words("english")

# %%
stopwords = ' '.join([word for word in n2.split() if word not in(stop)])

# %%
import nltk
from nltk.stem import WordNetLemmatizer 

# Init the Wordnet Lemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Tokenize: Split the sentence into words
word_list = nltk.word_tokenize(stopwords)
print(word_list)
# Out:
# ['consider', 'following', 'pairs', 'programme', 'project', 'ministry', 'drought-pror1e', 'ministry', 'area', 'programme', 'agriculture', 'desert', 'development', 'ministry', 'programme', 'environment', 'forests', 'national', 'watershed', 'ministry', 'development', 'project', 'rural', 'rainfed', 'areas', 'development', 'pairs', 'correctly', 'matched', '?']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', 
max_features= 1000, # keep top 1000 terms 
max_df = 0.5, 
smooth_idf=True)

# %%
X = vectorizer.fit_transform(word_list)

# %%
X.shape
# Out:
# (30, 21)

# %%
from sklearn.decomposition import TruncatedSVD

# SVD represent documents and terms in vectors 
svd_model = TruncatedSVD(n_components=1, algorithm='randomized', n_iter=100, random_state=122)

svd_model.fit(X)

len(svd_model.components_)
# Out:
# 1

# %%
stopwords
# Out:
# 'consider following pairs programme project ministry drought-pror1e ministry area programme agriculture desert development ministry programme environment forests national watershed ministry development project rural rainfed areas development pairs correctly matched?'

# %%
terms = vectorizer.get_feature_names()

for i, comp in enumerate(svd_model.components_):
    terms_comp = zip(terms, comp)
    sorted_terms = sorted(terms_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+":")
    for t in sorted_terms:
        print(t[0])
        print("")
# Out:
# Topic 0:
# ministry
#
# desert
#
# area
#
# national
#
# watershed
#
# pairs
#
# project
#
# development
#
# programme
#
# drought
